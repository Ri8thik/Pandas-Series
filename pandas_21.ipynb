# %%
import pandas as pd

# %%
data=pd.read_csv("student_results.csv")
data
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
data.pivot_table(index="Student ID")
# Out:
#             Class  Mobile Games hrs  Percantege  Sleeping hrs  \
# Student ID
# 1001           10                 5          50             9
# 1002           10                 0          80             8
# 1003           10                 4          60             8
# 1004           11                 5          45            10
# 1005           11                 0          75             7
# 1006           11                 0          96             7
# 1007           12                 0          80             6
# 1008           12                 0          90             6
# 1009           12                 4          60             8
# 1010           12                 0          85             9
#
#             Social Media usage hrs  Study hrs
# Student ID
# 1001                             3          2
# 1002                             2          6
# 1003                             2          3
# 1004                             1          0
# ...

# %%
data.pivot_table(index="Student ID",columns="Class")
# Out:
#            Mobile Games hrs           Percantege             Sleeping hrs  \
# Class                    10   11   12         10    11    12           10
# Student ID
# 1001                    5.0  NaN  NaN       50.0   NaN   NaN          9.0
# 1002                    0.0  NaN  NaN       80.0   NaN   NaN          8.0
# 1003                    4.0  NaN  NaN       60.0   NaN   NaN          8.0
# 1004                    NaN  5.0  NaN        NaN  45.0   NaN          NaN
# 1005                    NaN  0.0  NaN        NaN  75.0   NaN          NaN
# 1006                    NaN  0.0  NaN        NaN  96.0   NaN          NaN
# 1007                    NaN  NaN  0.0        NaN   NaN  80.0          NaN
# 1008                    NaN  NaN  0.0        NaN   NaN  90.0          NaN
# 1009                    NaN  NaN  4.0        NaN   NaN  60.0          NaN
# 1010                    NaN  NaN  0.0        NaN   NaN  85.0          NaN
#
#                       Social Media usage hrs           Study hrs
# ...

# %%
data.pivot_table(index="Student ID",columns="Class",aggfunc="sum")
# Out:
#            Mobile Games hrs           Percantege             Sleeping hrs  \
# Class                    10   11   12         10    11    12           10
# Student ID
# 1001                    5.0  NaN  NaN       50.0   NaN   NaN          9.0
# 1002                    0.0  NaN  NaN       80.0   NaN   NaN          8.0
# 1003                    4.0  NaN  NaN       60.0   NaN   NaN          8.0
# 1004                    NaN  5.0  NaN        NaN  45.0   NaN          NaN
# 1005                    NaN  0.0  NaN        NaN  75.0   NaN          NaN
# 1006                    NaN  0.0  NaN        NaN  96.0   NaN          NaN
# 1007                    NaN  NaN  0.0        NaN   NaN  80.0          NaN
# 1008                    NaN  NaN  0.0        NaN   NaN  90.0          NaN
# 1009                    NaN  NaN  4.0        NaN   NaN  60.0          NaN
# 1010                    NaN  NaN  0.0        NaN   NaN  85.0          NaN
#
#                       Social Media usage hrs           Study hrs
# ...

# %%
data.pivot_table(index="Student ID",columns="Class",aggfunc="max")
# Out:
#            Mobile Games hrs           Percantege             Sleeping hrs  \
# Class                    10   11   12         10    11    12           10
# Student ID
# 1001                    5.0  NaN  NaN       50.0   NaN   NaN          9.0
# 1002                    0.0  NaN  NaN       80.0   NaN   NaN          8.0
# 1003                    4.0  NaN  NaN       60.0   NaN   NaN          8.0
# 1004                    NaN  5.0  NaN        NaN  45.0   NaN          NaN
# 1005                    NaN  0.0  NaN        NaN  75.0   NaN          NaN
# 1006                    NaN  0.0  NaN        NaN  96.0   NaN          NaN
# 1007                    NaN  NaN  0.0        NaN   NaN  80.0          NaN
# 1008                    NaN  NaN  0.0        NaN   NaN  90.0          NaN
# 1009                    NaN  NaN  4.0        NaN   NaN  60.0          NaN
# 1010                    NaN  NaN  0.0        NaN   NaN  85.0          NaN
#
#                       Social Media usage hrs           Study hrs
# ...

# %%
data.pivot_table(index="Student ID",columns="Class",aggfunc="max",fill_value=0)
# Out:
#            Mobile Games hrs       Percantege         Sleeping hrs         \
# Class                    10 11 12         10  11  12           10  11 12
# Student ID
# 1001                      5  0  0         50   0   0            9   0  0
# 1002                      0  0  0         80   0   0            8   0  0
# 1003                      4  0  0         60   0   0            8   0  0
# 1004                      0  5  0          0  45   0            0  10  0
# 1005                      0  0  0          0  75   0            0   7  0
# 1006                      0  0  0          0  96   0            0   7  0
# 1007                      0  0  0          0   0  80            0   0  6
# 1008                      0  0  0          0   0  90            0   0  6
# 1009                      0  0  4          0   0  60            0   0  8
# 1010                      0  0  0          0   0  85            0   0  9
#
#            Social Media usage hrs       Study hrs
# ...

# %%
data.pivot_table(index="Student ID",columns="Class",aggfunc="max",fill_value=0,dropna=False)
# Out:
#            Mobile Games hrs       Percantege         Sleeping hrs         \
# Class                    10 11 12         10  11  12           10  11 12
# Student ID
# 1001                      5  0  0         50   0   0            9   0  0
# 1002                      0  0  0         80   0   0            8   0  0
# 1003                      4  0  0         60   0   0            8   0  0
# 1004                      0  5  0          0  45   0            0  10  0
# 1005                      0  0  0          0  75   0            0   7  0
# 1006                      0  0  0          0  96   0            0   7  0
# 1007                      0  0  0          0   0  80            0   0  6
# 1008                      0  0  0          0   0  90            0   0  6
# 1009                      0  0  4          0   0  60            0   0  8
# 1010                      0  0  0          0   0  85            0   0  9
#
#            Social Media usage hrs       Study hrs
# ...

# %%
data.pivot_table(index="Student ID",columns="Class",aggfunc="max",fill_value=0,margins=True)
# Out:
#            Mobile Games hrs           Percantege             Sleeping hrs      \
# Class                    10 11 12 All         10  11  12 All           10  11
# Student ID
# 1001                      5  0  0   5         50   0   0  50            9   0
# 1002                      0  0  0   0         80   0   0  80            8   0
# 1003                      4  0  0   4         60   0   0  60            8   0
# 1004                      0  5  0   5          0  45   0  45            0  10
# 1005                      0  0  0   0          0  75   0  75            0   7
# 1006                      0  0  0   0          0  96   0  96            0   7
# 1007                      0  0  0   0          0   0  80  80            0   0
# 1008                      0  0  0   0          0   0  90  90            0   0
# 1009                      0  0  4   4          0   0  60  60            0   0
# 1010                      0  0  0   0          0   0  85  85            0   0
# ...
